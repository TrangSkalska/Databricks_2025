# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, avg, min, max, count

file_location = "file:/Workspace/Users/ts149509@student.sgh.waw.pl/Data/telco.csv"
file_type = "csv"

spark = SparkSession.builder.getOrCreate()

# 1) Read the CSV
df = (
    spark.read
         .option("header", "true")
         .option("inferSchema", "true")
         .csv(file_location)
)

df.printSchema()
df.show(5)

# %%
# %fs ls /FileStore/
